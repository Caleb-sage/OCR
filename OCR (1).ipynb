# %%
import pytesseract as pt
import cv2
import matplotlib.pyplot as plt
import pandas as pd

# %%
pt.pytesseract.tesseract_cmd = r"C:\Users\User\AppData\Local\Programs\Tesseract-OCR\tesseract.exe"

# %%
path = r"C:\Users\User\Desktop\Graduate Rotational Internship Program (GRIP)\Screenshot 2024-02-20 153433.png"

# %%
cv2.imread(path)
# Out:
# array([[[ 29,  29,  29],
#         [ 29,  29,  29],
#         [ 29,  29,  29],
#         ...,
#         [ 29,  29,  29],
#         [ 29,  29,  29],
#         [ 29,  29,  29]],
#
#        [[ 29,  29,  29],
#         [ 29,  29,  29],
#         [ 29,  29,  29],
#         ...,
#         [ 29,  29,  29],
#         [ 29,  29,  29],
#         [ 29,  29,  29]],
#
#        [[112, 112, 112],
#         [112, 112, 112],
#         [112, 112, 112],
#         ...,
#         [112, 112, 112],
#         [112, 112, 112],
#         [112, 112, 112]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img = cv2.imread(path)
plt.show()

# %%
plt.imshow(cv2.imread(path))

# %%
print(pt.image_to_string(img))
# Out:
# C. This is normal operation for your business.
# D. This could be a precursor to an attack.
#
# 68. How often is the ISF Standard of Good Practice updated?
# A. annual
# 8. biannually
# C. bimonthly
# D. monthly
#
# 69. Your incident response team is unable to contain an incident because they lack authority
# to take action without management approval. Which critical step in the preparation
# phase did your team skip?
#
# A. From an incident response committee to oversee any incidents that may occur.
#
# B. Get preauthorized to take unilateral action and make or direct emergency changes.
# C._ Bring management in as leadership on the incident response team.
#
# D. Assign a head of the emergency response team who has the correct authority
#
# 70. NIST SP 800-53 is one of two important control frameworks used in cybersecurity. What
# is the other one?
# A. 18027001
# B. NIST SP 800-54
# C. 180 27002
# D. NIST SP 751-51
#
# ...

# %%
plt.imshow(cv2.imread(r"\Users\User\Desktop\Graduate Rotational Internship Program (GRIP)\Screenshot 2024-02-20 220220.png"))
plt.title("Picture One")
plt.show()

# %%
print(pt.image_to_string(cv2.imread(r"\Users\User\Desktop\Graduate Rotational Internship Program (GRIP)\Screenshot 2024-02-20 220220.png")))
# Out:
# Case Studies
#
# » GoogLeNet. The ILSVRC 2014 winner was a Convolutional Network
# from Szegedy et al. from Google.
#
# * Its main contribution was the development of an Inception Module that
# dramatically reduced the number of parameters in the network (4M,
# compared to AlexNet with 60M).
#
# » Uses Average Pooling instead of Fully Connected layers at the top of the
# ConvNet
#
# » There are also several followup versions to the GoogLeNet, most
# recently Inception-v4.
#
# « VGGNet. The runner-up in ILSVRC 2014 was the network from Karen
# Simonyan and Andrew Zisserman.
#
# » Showed that the depth of the network is a critical component for good
# performance. Their final best network contains 16 CONV/FC layers
#
# » and, apfeatures an extremely homogeneous architecture that only performs
# 3x3 convolutions and 2x2 pooling from the beginning to the end.
# Their pretrained model is available for plug and play use in Caffe. A
# ...

# %%
print(pt.image_to_string(cv2.imread(r"C:\Users\User\Desktop\Graduate Rotational Internship Program (GRIP)\Screenshot 2024-02-20 220356.png")))
# Out:
# 2. Can you implement the logical AND function Y = X1 A Xz in a single unit? If so, give weights that
# achiove this. If not, explain the problem.
#
# + SOLUTION: Similar to previous part, we can obtain [wp = —1.5, 1 = 1,2 = I]
#
# 3, It is impossible to implement the EXCLUSIVE-OR function ¥ = X; @ Xp in a single unit. However,
# ‘you can do it using a multiple unit neural network. Please do. Use the smallest. number of units you
# can. Draw your network, and show all weights of each unit.
#
# %& SOLUTION: It can be represented by 2 neural network with two nodes in the hidden layer. Input
# ‘weights for node 1 in the hidden layer would be [wi = —0.5, = 1, w» = —I], input weights for node 2
# in the hidden layer would be [uv = —0.5,1n; = —1, 102 = 1], and input weights forthe output node would
# be [wo = —0.8, un = 1,w2 = 1}
#
# 4, Create a neural network with only one hidden layer (of any number of units) chat implements (AV
# ...

# %%
plt.imshow(cv2.imread(r"C:\Users\User\Desktop\Graduate Rotational Internship Program (GRIP)\Screenshot 2024-02-20 220356.png"))
plt.show()

# %%
print(pt.image_to_string(cv2.imread(r"C:\Users\User\Desktop\Graduate Rotational Internship Program (GRIP)\Screenshot 2024-02-20 221945.png")))
# Out:
# a=b=c-1
# print(a, b,c)
# # Output: 111
#
# When using such cascading assignment, itis important to note that all three variables a, b and ¢ refer to the same
# objectin memory, an int object with the value of 1. In other words, 2, band c are three different names given to the
# ‘same int object. Assigning a different object to one of them afterwards doesn't change the others, just as expected:
#
# a=b=c=1 #all three names a, b and c refer to same int object with value 1
# print(a, b,c)
#
# # Output: 111
#
# b=2 #b now refers to another int object, one with a value of 2
#
# print(a, b, ¢)
# # Output: 121 # so output is as expected.
#
# The above is also true for mutable types (like List, dict, etc.) just as itis true for immutable types (like int, string,
# ‘tuple, etc)
#
# x=y=[7, 8, 9] #x andy refer to the sone list object just created, [7, 8, 9]
# x=[13, 8,9] # x now refers to a different list object just created, [13, 8, 9]
# ...

# %%
plt.imshow(cv2.imread(r"C:\Users\User\Desktop\Graduate Rotational Internship Program (GRIP)\Screenshot 2024-02-20 222157.png"))

# %%
print(pt.image_to_string(cv2.imread(r"C:\Users\User\Desktop\Graduate Rotational Internship Program (GRIP)\Screenshot 2024-02-20 222157.png")))
# Out:
# Structured Query Language
#
# Keyword Description
# ADD ‘Add a new column to an existing table. Eg: ALTER TABLE customers ADD email_address VARCHAR(255);
# ALTER TABLE ‘Adds, deletes, or edits columns/constraints in a table. Eg: ALTER TABLE customers DROP COLUMN email_address;
# ALTER COLUMN Changes the data type of a table's column. Eg: ALTER TABLE customers ALTER COLUMN phone varchar(50)
# AS Renames a table or column with an alias value that only exists for the duration of the query. Eg: SELECT name AS customer_name, phone,
# postalCode FROM customers;
# asc Used with ORDER BY to retum the data in ascending order.
# CHECK ‘Adds a constraint that limits the value which can be added to a column. Eg: CREATE TABLE Users(firstName varchar(255),age INT,
# CHECK(age>'10));
# eee Creates a new database. Eg: CREATE DATABASE my website;
#
# ...

# %%
cv2.imread(d)
# Out:
# array([[[ 50,  50,  50],
#         [ 50,  50,  50],
#         [ 50,  50,  50],
#         ...,
#         [ 50,  50,  50],
#         [ 50,  50,  50],
#         [ 50,  50,  50]],
#
#        [[ 50,  50,  50],
#         [ 50,  50,  50],
#         [ 50,  50,  50],
#         ...,
#         [ 50,  50,  50],
#         [ 50,  50,  50],
#         [ 50,  50,  50]],
#
#        [[ 84,  84,  84],
#         [ 84,  84,  84],
#         [ 84,  84,  84],
#         ...,
#         [ 84,  84,  84],
#         [ 84,  84,  84],
#         [ 84,  84,  84]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img_boxes = pt.image_to_boxes(img)

# %%
img.shape
# Out:
# (847, 842, 3)

# %%
imgH, imgW, _ = img.shape

# %%
imgW
# Out:
# 842

# %%
imgH
# Out:
# 847

# %%
print (img_boxes)
# Out:
# C 129 725 137 736 0
# . 139 725 141 727 0
# T 154 725 160 737 0
# h 154 725 170 737 0
# i 172 725 175 736 0
# s 176 725 182 733 0
# i 187 725 189 736 0
# s 190 725 196 733 0
# n 202 725 209 733 0
# o 210 725 218 733 0
# r 218 725 227 737 0
# m 220 725 237 733 0
# a 234 725 243 737 0
# l 239 725 250 737 0
# o 255 725 263 733 0
# p 264 722 272 733 0
# e 273 725 280 733 0
# r 277 722 285 736 0
# a 282 725 294 733 0
# t 293 722 299 736 0
# i 294 725 303 736 0
# o 304 725 313 733 0
# n 314 725 321 733 0
# f 326 725 331 737 0
# o 331 725 339 733 0
# r 341 725 346 733 0
# y 351 722 357 733 0
# o 350 722 366 733 0
# u 367 725 374 733 0
# r 376 725 381 733 0
# b 386 725 394 737 0
# u 395 725 402 733 0
# s 403 725 409 733 0
# i 410 725 413 736 0
# n 415 725 422 733 0
# e 421 725 429 737 0
# s 423 725 437 733 0
# s 438 725 444 733 0
# . 446 725 448 727 0
# D 129 702 138 713 0
# . 140 702 142 704 0
# T 154 702 160 714 0
# h 154 702 170 714 0
# i 172 702 175 713 0
# s 176 702 182 710 0
# ...

# %%
img_boxes
# Out:
# 'C 129 725 137 736 0\n. 139 725 141 727 0\nT 154 725 160 737 0\nh 154 725 170 737 0\ni 172 725 175 736 0\ns 176 725 182 733 0\ni 187 725 189 736 0\ns 190 725 196 733 0\nn 202 725 209 733 0\no 210 725 218 733 0\nr 218 725 227 737 0\nm 220 725 237 733 0\na 234 725 243 737 0\nl 239 725 250 737 0\no 255 725 263 733 0\np 264 722 272 733 0\ne 273 725 280 733 0\nr 277 722 285 736 0\na 282 725 294 733 0\nt 293 722 299 736 0\ni 294 725 303 736 0\no 304 725 313 733 0\nn 314 725 321 733 0\nf 326 725 331 737 0\no 331 725 339 733 0\nr 341 725 346 733 0\ny 351 722 357 733 0\no 350 722 366 733 0\nu 367 725 374 733 0\nr 376 725 381 733 0\nb 386 725 394 737 0\nu 395 725 402 733 0\ns 403 725 409 733 0\ni 410 725 413 736 0\nn 415 725 422 733 0\ne 421 725 429 737 0\ns 423 725 437 733 0\ns 438 725 444 733 0\n. 446 725 448 727 0\nD 129 702 138 713 0\n. 140 702 142 704 0\nT 154 702 160 714 0\nh 154 702 170 714 0\ni 172 702 175 713 0\ns 176 702 182 710 0\nc 189 702 195 714 0\no 186 702 202 710 0\nu 203 702 
# ...

# %%
for i in img_boxes.splitlines():
    print(i.split(' '))
# Out:
# ['C', '129', '725', '137', '736', '0']
# ['.', '139', '725', '141', '727', '0']
# ['T', '154', '725', '160', '737', '0']
# ['h', '154', '725', '170', '737', '0']
# ['i', '172', '725', '175', '736', '0']
# ['s', '176', '725', '182', '733', '0']
# ['i', '187', '725', '189', '736', '0']
# ['s', '190', '725', '196', '733', '0']
# ['n', '202', '725', '209', '733', '0']
# ['o', '210', '725', '218', '733', '0']
# ['r', '218', '725', '227', '737', '0']
# ['m', '220', '725', '237', '733', '0']
# ['a', '234', '725', '243', '737', '0']
# ['l', '239', '725', '250', '737', '0']
# ['o', '255', '725', '263', '733', '0']
# ['p', '264', '722', '272', '733', '0']
# ['e', '273', '725', '280', '733', '0']
# ['r', '277', '722', '285', '736', '0']
# ['a', '282', '725', '294', '733', '0']
# ['t', '293', '722', '299', '736', '0']
# ['i', '294', '725', '303', '736', '0']
# ['o', '304', '725', '313', '733', '0']
# ['n', '314', '725', '321', '733', '0']
# ['f', '326', '725', '331', '737', '0']
# ...

# %%
type(img_boxes)
# Out:
# str

# %%
for i in img_boxes.splitlines():
    boxes = img_boxes.split(' ')
    x,y,w,h = int(boxes[1]), int(boxes[2]),int(boxes[3]),int(boxes[4])
    cv2.rectangle(img, (x,imgH-y), (w,imgH-h), (00,0,255),3)

# %%
 cv2.rectangle(img, (x,imgH-y), (w,imgH-h), (00,0,255),3)
# Out:
# array([[[ 29,  29,  29],
#         [ 29,  29,  29],
#         [ 29,  29,  29],
#         ...,
#         [ 29,  29,  29],
#         [ 29,  29,  29],
#         [ 29,  29,  29]],
#
#        [[ 29,  29,  29],
#         [ 29,  29,  29],
#         [ 29,  29,  29],
#         ...,
#         [ 29,  29,  29],
#         [ 29,  29,  29],
#         [ 29,  29,  29]],
#
#        [[112, 112, 112],
#         [112, 112, 112],
#         [112, 112, 112],
#         ...,
#         [112, 112, 112],
#         [112, 112, 112],
#         [112, 112, 112]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
type(img_boxes)
# Out:
# str

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
((50%20) == 0)
# Out:
# False

# %% [markdown]
# <h2> Video Demo </h2>

# %%
font_scale = 1.5
font = cv2.FONT_HERSHEY_PLAIN
#cap = cv2.VideoCapture(0)
cap = cv2.VideoCapture(r"C:\Users\User\Videos\DU Recorder Videos\20240220_164911_DURecorder.mp4")
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open Webcam")
contr = 0
while True:
    ret,frame = cap.read()
    contr = contr + 1
    if ((contr % 20 ) == 0) :
        
        imgH, imgW, _ = frame.shape
        x1,y1,w1,h1 = 0,0,imgH,imgW
        imgchar = pt.image_to_string(frame)
        imgboxes = pt.image_to_boxes(frame)
        for boxes in imgboxes.splitlines():
            boxes = boxes.split(' ')
            x,y,w,h = int(boxes[1]), int(boxes[2]), int(boxes[3]),int(boxes[4])
            cv2.rectangle(frame,(x, imgH-y), (w,imgH-h), (0,0,255),3)
            
        cv2.putText(frame, imgchar, (x1 + int(w1/50), y1 + int(h1/50)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255),2)
        font = cv2.FONT_HERSHEY_SIMPLEX
        
        cv2.imshow("Text Detection Algorithm", frame)
        
        if cv2.waitKey(2) & 0xFF == ord('q'):
            break
            
cap.release()
cv2.destroyAllWindows()

# %%
plt.imshow(cv2.imread(r"C:\Users\User\Desktop\Graduate Rotational Internship Program (GRIP)\result.png"))
plt.title("Result Output of OCR")
plt.show()
